# %%
txt = "Hello.World.How.Are.You?"
# Out:
# "Hello.World.How.Are.You?"

# %%
split(txt, '.')
# Out:
# 5-element Vector{SubString{String}}:
#  "Hello"
#  "World"
#  "How"
#  "Are"
#  "You?"

# %%
rsplit(txt, '.')
# Out:
# 5-element Vector{SubString{String}}:
#  "Hello"
#  "World"
#  "How"
#  "Are"
#  "You?"

# %%
txt[4:7]
# Out:
# "lo.W"
