// %%
type Cookie = {
  flavor: string;
  calories: number;
  servingSize?: number;
};

// %%
type Stock = {
  symbol: string;
  price: number;
};

// %%
let c1: Cookie = {
  flavor: "Chocolate Chip",
  calories: 200,
  servingSize: 2
};

// %%
typeof c1;
// Out:
// object

// %%
c1 instanceof Cookie;
// Out:
// 1:15 - 'Cookie' only refers to a type, but is being used as a value here.
